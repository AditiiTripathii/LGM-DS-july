# %%
import pandas as pd
dat = pd.read_csv("IRIS.csv")
dat.head()
#isnull() is used to detect NULL values
dat.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
dat = pd.read_csv("IRIS.csv")
#dropna() funct will drop rows with atleast one NULL value
dat.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             0.0          3.2           1.3          0.2     Iris-setosa
# 3             0.0          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dat = pd.read_csv("IRIS.csv")
#fillna() funct will fill the NULL value by described value
dat["sepal_length"].fillna("5.0", inplace = True)
dat
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             0.0          3.2           1.3          0.2     Iris-setosa
# 3             0.0          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[1, 2, 4, np.nan],
        'Second Score': [3, 4, np.nan, 5],
        'Third Score':[6, 7, 8, 9]}
dat = pd.DataFrame(dict)
dat.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False        False
# 1        False         False        False
# 2        False          True        False
# 3         True         False        False

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[1, 2, 4, np.nan],
        'Second Score': [3, 4, np.nan, 5],
        'Third Score':[6, 7, 8, 9]}
dat = pd.DataFrame(dict)
dat.dropna()
# Out:
#    First Score  Second Score  Third Score
# 0          1.0           3.0            6
# 1          2.0           4.0            7

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[1, 2, 4, np.nan],
        'Second Score': [3, 4, np.nan, 5],
        'Third Score':[6, 7, 8, 9]}
dat = pd.DataFrame(dict)
dat["First Score"].fillna("5", inplace = True)
dat
# Out:
#   First Score  Second Score  Third Score
# 0         1.0           3.0            6
# 1         2.0           4.0            7
# 2         4.0           NaN            8
# 3           5           5.0            9

# %%
data = pd.read_csv('IRIS.csv')

x = data['sepal_length']
y = data['sepal_width']

plt.bar(x,y)
plt.title("Bar Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
data = pd.read_csv('IRIS.csv')

x = data['sepal_length']
#y = data['sepal_width']

plt.hist(x)
plt.title("Histogram Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %%
data = pd.read_csv('IRIS.csv')

x = data['sepal_length']
y = data['sepal_width']

plt.scatter(x,y)
plt.title("Scatter Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()
